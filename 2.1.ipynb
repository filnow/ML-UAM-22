# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data2.csv')

X = data.iloc[:,1].to_numpy()
y = data.iloc[:,2].to_numpy()

plt.xlabel("Druga kolumna")
plt.ylabel("Trzecia kolumna")
plt.scatter(X,y)
plt.show()
